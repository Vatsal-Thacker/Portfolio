# %% [markdown]
# # <font color = red> Neelam Stores </font> - <font color = blue> Best LG Brand Shop</font>

# %% [markdown]
# ## <font color = orange> Importing Dependecies</font>

# %%
import pandas as pd

# %% [markdown]
# ## <font color = Maroon> Read the Datasets </font>

# %%
df1 = pd.read_excel(r"C:\Users\vatsa\OneDrive\Documents\LG\Neelam Data\Neelam Appl EBO GFK data Dec 2021.xlsx")
df2 = pd.read_excel(r"C:\Users\vatsa\OneDrive\Documents\LG\Neelam Data\EBO sell out report jan 22 Neelam.xlsx")
df3 = pd.read_excel(r"C:\Users\vatsa\OneDrive\Documents\LG\Neelam Data\Neelam Appl GFK data Feb 2022.xlsx")
df4 = pd.read_excel(r"C:\Users\vatsa\OneDrive\Documents\LG\Neelam Data\GFK data March 2022 Neelam Appl.xlsx")
df5 = pd.read_excel(r"C:\Users\vatsa\OneDrive\Documents\LG\Neelam Data\Neelam Appl EBO data April 2022.xlsx")
df6 = pd.read_excel(r"C:\Users\vatsa\OneDrive\Documents\LG\Neelam Data\GFK EBO May 2022 Neelam Appl.xlsx")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BRAND             54 non-null     object
#  1   BO                54 non-null     object
#  2   Dealer Code       54 non-null     object
#  3   Dealer Name       54 non-null     object
#  4   Invoice No        54 non-null     object
#  5   MONTH             54 non-null     object
#  6   Model No          54 non-null     object
#  7   Model Suffix      54 non-null     object
#  8   Product Category  54 non-null     object
#  9   Product Group     54 non-null     object
#  10  Quantity          54 non-null     int64
#  11  Basic Price       54 non-null     int64
# dtypes: int64(2), object(10)
# memory usage: 5.2+ KB

# %% [markdown]
# ## <font color = navy> Changing the columns </font>

# %% [markdown]
# ### For df1

# %%
df1_pd = pd.DataFrame(df1)

# %%
df1_pd.colums = [['State', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix', 
             'Product Category', 'Product Group', 'Quantity', 'Basic Price']]

# %%
df1_pd
# Out:
#    BRAND   BO   Dealer Code        Dealer Name     Invoice No     MONTH  \
# 0    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0782  DEC'2021
# 1    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0796  DEC'2021
# 2    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0795  DEC'2021
# 3    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0793  DEC'2021
# 4    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0792  DEC'2021
# 5    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0791  DEC'2021
# 6    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0790  DEC'2021
# 7    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0790  DEC'2021
# 8    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0789  DEC'2021
# 9    GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0788  DEC'2021
# 10   GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0787  DEC'2021
# 11   GUJ  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0785  DEC'2021
# ...

# %% [markdown]
# ### For df2

# %%
df2_pd = pd.DataFrame(df2)

# %%
df2_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix', 
             'Product Category', 'Product Group', 'Quantity', 'Basic Price']]
# Out:
# C:\Users\vatsa\AppData\Local\Temp\ipykernel_25848\538947409.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df2_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix',

# %%
df2_pd
# Out:
#    BRAND   BO   Dealer Code        Dealer Name     Invoice No     MONTH  \
# 0     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0863  JAN'2022
# 1     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0797  JAN'2022
# 2     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0797  JAN'2022
# 3     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0802  JAN'2022
# 4     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0801  JAN'2022
# ..   ...  ...           ...                ...            ...       ...
# 76    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0803  JAN'2022
# 77    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0800  JAN'2022
# 78    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0799  JAN'2022
# 79    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0821  JAN'2022
# 80    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0806  JAN'2022
#
#        Model No         Model Suffix Product Category Product Group  Quantity  \
# ...

# %% [markdown]
# ### For df3

# %%
df3_pd = pd.DataFrame(df3)

# %%
df3_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix', 
             'Product Category', 'Product Group', 'Quantity', 'Basic Price']]
# Out:
# C:\Users\vatsa\AppData\Local\Temp\ipykernel_25848\1401074761.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df3_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix',

# %%
df3_pd
# Out:
#    BRAND   BO   DEALER CODE        DEALER NAME     Invoice No Invoice Date  \
# 0     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0903   2022-02-20
# 1     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0880   2022-02-09
# 2     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0885   2022-02-12
# 3     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0885   2022-02-12
# 4     LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0921   2022-02-26
# ..   ...  ...           ...                ...            ...          ...
# 78    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0884   2022-02-11
# 79    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0897   2022-02-17
# 80    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0896   2022-02-17
# 81    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0924   2022-02-27
# 82    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0924   2022-02-27
#
# ...

# %% [markdown]
# ### For DF4

# %%
df4_pd = pd.DataFrame(df4)

# %%
df4_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix', 
             'Product Category', 'Product Group', 'Quantity', 'Basic Price']]
# Out:
# C:\Users\vatsa\AppData\Local\Temp\ipykernel_25848\946465755.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df4_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix',

# %%
df4_pd
# Out:
#     BRAND   BO   DEALER CODE        DEALER NAME     Invoice No Invoice Date  \
# 0      LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0999   2022-03-20
# 1      LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0985   2022-03-16
# 2      LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0951   2022-03-07
# 3      LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0942   2022-03-02
# 4      LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0953   2022-03-07
# ..    ...  ...           ...                ...            ...          ...
# 191    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/1032   2022-03-27
# 192    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/1032   2022-03-27
# 193    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/1032   2022-03-27
# 194    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0994   2022-03-19
# 195    LG  AHM  IN051543001B  NEELAM APPLIANCES  NA/21-22/0994   2022-03-19
#
# ...

# %% [markdown]
# ### For Df5

# %%
df5_pd = pd.DataFrame(df5)

# %%
df5_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix', 
             'Product Category', 'Product Group', 'Quantity', 'Basic Price']]
# Out:
# C:\Users\vatsa\AppData\Local\Temp\ipykernel_25848\1657304646.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df5_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix',

# %%
df5_pd
# Out:
#     Brand Name   Distributor Name     Invoice No Invoice Date     Model No  \
# 0           LG  NEELAM APPLIANCES  NA/22-23/0001   2022-04-01  GL-B191KSPX
# 1           LG  NEELAM APPLIANCES  NA/22-23/0001   2022-04-01  32LM636BPTB
# 2           LG  NEELAM APPLIANCES  NA/22-23/0002   2022-04-01  GC-B247SQUV
# 3           LG  NEELAM APPLIANCES  NA/22-23/0003   2022-04-01   PSUQ19HNZE
# 4           LG  NEELAM APPLIANCES  NA/22-23/0003   2022-04-01   PSNQ19HNZE
# ..         ...                ...            ...          ...          ...
# 203         LG  NEELAM APPLIANCES  NA/22-23/0136   2022-04-30   PSNQ19ENYE
# 204         LG  NEELAM APPLIANCES  NA/22-23/0137   2022-04-30  GL-B201ASCD
# 205         LG  NEELAM APPLIANCES  NA/22-23/0138   2022-04-30  PSUQ12CNXE1
# 206         LG  NEELAM APPLIANCES  NA/22-23/0138   2022-04-30  PSNQ12CNXE1
# 207         LG  NEELAM APPLIANCES  NA/22-23/0139   2022-04-30   T70SJSF2ZA
#
# ...

# %% [markdown]
# ### For DF6

# %%
df6_pd = pd.DataFrame(df6)

# %%
df6_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix', 
             'Product Category', 'Product Group', 'Quantity', 'Basic Price']]
# Out:
# C:\Users\vatsa\AppData\Local\Temp\ipykernel_25848\3120612102.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df6_pd.colums = [['Brand', 'BO', 'State', 'Dealer Code', 'Dealer Name', 'Invoice No', 'Month', 'Model No', 'Model Suffix',

# %%
df6_pd
# Out:
#     BRAND NAME         DEALER NAME     Invoice No Invoice Date     Model No  \
# 0           AHM  NEELAM APPLIANCES  NA/22-23/0197   2022-05-12   PSNQ19BWZF
# 1           AHM  NEELAM APPLIANCES  NA/22-23/0197   2022-05-12   PSUQ19BWZF
# 2           AHM  NEELAM APPLIANCES  NA/22-23/0274   2022-05-28  GL-T342VPZX
# 3           AHM  NEELAM APPLIANCES  NA/22-23/0213   2022-05-14  43UP7740PTZ
# 4           AHM  NEELAM APPLIANCES  NA/22-23/0223   2022-05-16   PSUQ19BWZF
# ..          ...                ...            ...          ...          ...
# 224         AHM  NEELAM APPLIANCES  NA/22-23/0262   2022-05-25    T10SJMB1Z
# 225         AHM  NEELAM APPLIANCES  NA/22-23/0203   2022-05-13   PSUQ19BWXF
# 226         AHM  NEELAM APPLIANCES  NA/22-23/0203   2022-05-13   PSNQ19BWXF
# 227         AHM  NEELAM APPLIANCES  NA/22-23/0154   2022-05-03   PSNQ19BWXF
# 228         AHM  NEELAM APPLIANCES  NA/22-23/0154   2022-05-03   PSUQ19BWXF
#
# ...

# %% [markdown]
# ## <font color = purple> Merging the Datasets </font>

# %%
df = pd.concat([df1_pd, df2_pd, df3_pd, df4_pd, df5_pd, df6_pd])

# %% [markdown]
# ## <font color = Navy> Export the Final Merge File</font>

# %%
df.to_excel('Sales Data.xlsx', index=False)
